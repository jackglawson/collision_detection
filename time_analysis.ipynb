# %%
# https://www.toptal.com/game/video-game-physics-part-ii-collision-detection-for-solid-objects

# %%
import numpy as np
import random
import time
import matplotlib.pyplot as plt
import math

# %%
from colliding_balls import Ball, colliding

# %%
# %load_ext line_profiler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-df8a33df4eaf> in <module>
# ----> 1 get_ipython().run_line_magic('load_ext', 'line_profiler')
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2315                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2316             with self.builtin_trap:
# -> 2317                 result = fn(*args, **kwargs)
#    2318             return result
#    2319
#
# <decorator-gen-65> in load_ext(self, module_str)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\IPython\core\magics\extension.py in load_ext(self, module_str)
#      31         if not module_str:
#      32             raise UsageError('Missing module name.')
# ---> 33         res = self.shell.extension_manager.load_extension(module_str)
#      34
#      35         if res == 'already loaded':
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\IPython\core\extensions.py in load_extension(self, module_str)
#      78             if module_str not in sys.modules:
#      79                 with prepended_to_syspath(self.ipython_extension_dir):
# ---> 80                     mod = import_module(module_str)
#      81                     if mod.__file__.startswith(self.ipython_extension_dir):
#      82                         print(("Loading extensions from {dir} is deprecated. "
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'line_profiler'

# %%
def brute(balls):
    colliding_pairs = []
    for i in range(n):
        for j in range(i+1, n):
            b1 = balls[i]
            b2 = balls[j]
            dist = math.sqrt((b1.x - b2.x)**2 + (b1.y - b2.y)**2 + (b1.z - b2.z)**2)
            if dist < b1.radius + b2.radius:
                colliding_pairs.append((i, j))
    return colliding_pairs

# %%
brute_times = []
smart_times = []
ns = np.linspace(1, 6000, 11, dtype=int)

# %%
for n in ns:
    balls = [Ball(1, random.uniform(0, 100), random.uniform(0, 100), random.uniform(0, 100)) for _ in range(n)]
        
    s = time.time()
    c1 = colliding(balls)
    f = time.time()
    smart_times.append(f-s)
    
    s = time.time()
    c2 = brute(balls)
    f = time.time()
    brute_times.append(f-s)
    
    print(n, c1==c2)
# Out:
# 1 True
# 600 True
# 1200 True
# 1800 True
# 2400 True
# 3000 True
# 3600 True
# 4200 True
# 4800 True
# 5400 True
# 6000 True

# %%
plt.plot(ns, brute_times, label="brute")
plt.plot(ns, smart_times, label="smart")
plt.legend()
plt.show()

# %%
c2
# Out:
# [(1, 5576),
#  (3, 3826),
#  (5, 4174),
#  (11, 4059),
#  (13, 4958),
#  (28, 5580),
#  (29, 4319),
#  (32, 3557),
#  (33, 505),
#  (36, 1126),
#  (37, 3067),
#  (42, 2711),
#  (44, 4355),
#  (50, 730),
#  (53, 2501),
#  (60, 1892),
#  (65, 2551),
#  (66, 1753),
#  (73, 1034),
#  (93, 1886),
#  (93, 5275),
#  (112, 1787),
#  (112, 2474),
#  (112, 5328),
#  (114, 2116),
#  (114, 5331),
#  (125, 2967),
#  (129, 1775),
#  (130, 2447),
#  (140, 5956),
#  (151, 569),
#  (153, 5016),
#  (154, 2078),
#  (155, 495),
#  (161, 1331),
#  (170, 5195),
#  (173, 1468),
#  (180, 4493),
#  (186, 2832),
#  (190, 498),
#  (192, 881),
#  (195, 5529),
#  (201, 2680),
#  (209, 1473),
#  (211, 771),
#  (212, 3693),
#  (217, 4291),
#  (227, 281),
#  (227, 4167),
#  (227, 5287),
#  (233, 4210),
#  (234, 2700),
#  (236, 2083),
#  (249, 4181),
#  (249, 4565),
#  (259, 1822),
#  (262, 4185),
#  (263, 1094),
#  (275, 2232),
#  (279, 2739),
#  (280, 1347),
#  (281, 1598),
#  (281, 4167),
#  (283, 521),
#  (284, 3818),
#  (293, 4073),
#  (295, 2803),
#  (303, 366),
#  (303, 2896),
#  (314, 3083),
#  (329, 3152),
#  (341, 751),
#  (348, 1699),
#  (366, 2896),
#  (370, 2013),
#  (394, 3727),
#  (396, 3627),
#  (399, 4538),
#  (399, 5793),
#  (404, 894),
#  (414, 4841),
#  (433, 3246),
#  (433, 3573),
#  (439, 1031),
#  (444, 3754),
#  (447, 1848),
#  (448, 4108),
#  (451, 2643),
#  (452, 1214),
#  (452, 1818),
#  (460, 3356),
#  (466, 4697),
#  (490, 4991),
#  (496, 3856),
#  (496, 4027),
#  (501, 2002),
#  (501, 4366),
#  (503, 2016),
#  (506, 1089),
#  (513, 4420),
#  (519, 5375),
#  (528, 1937),
#  (532, 5111),
#  (534, 1690),
#  (535, 1026),
#  (542, 2531),
#  (550, 3027),
#  (560, 2649),
#  (563, 3167),
#  (566, 3942),
#  (567, 5259),
#  (572, 4566),
#  (582, 4555),
#  (592, 1804),
#  (602, 4634),
#  (612, 4506),
#  (615, 2608),
#  (620, 5087),
#  (623, 4169),
#  (647, 4124),
#  (649, 5502),
#  (651, 2522),
#  (679, 3254),
#  (680, 5358),
#  (683, 4338),
#  (685, 2199),
#  (697, 3616),
#  (699, 4671),
#  (721, 5381),
#  (722, 1873),
#  (725, 1586),
#  (741, 5307),
#  (749, 5610),
#  (757, 1856),
#  (765, 4361),
#  (770, 2409),
#  (772, 1181),
#  (773, 2172),
#  (775, 3000),
#  (776, 1289),
#  (786, 2416),
#  (789, 3732),
#  (791, 1808),
#  (795, 1144),
#  (796, 5554),
#  (800, 3735),
#  (802, 1054),
#  (814, 4535),
#  (815, 4867),
#  (822, 3724),
#  (824, 2099),
#  (829, 2576),
#  (830, 2879),
#  (831, 3394),
#  (834, 3329),
#  (838, 2211),
#  (842, 3118),
#  (851, 3045),
#  (855, 3697),
#  (858, 4477),
#  (868, 4803),
#  (869, 1764),
#  (869, 2021),
#  (873, 5957),
#  (883, 2660),
#  (884, 2749),
#  (887, 4075),
#  (892, 5732),
#  (898, 2291),
#  (901, 2690),
#  (901, 3769),
#  (905, 1553),
#  (917, 2457),
#  (918, 2653),
#  (926, 1371),
#  (927, 3091),
#  (927, 3964),
#  (939, 1037),
#  (945, 4223),
#  (951, 2308),
#  (952, 2591),
#  (962, 5383),
#  (965, 4397),
#  (969, 3224),
#  (972, 5978),
#  (973, 5024),
#  (977, 5642),
